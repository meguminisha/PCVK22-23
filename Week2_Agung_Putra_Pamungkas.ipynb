# %% [markdown]
# <a href="https://colab.research.google.com/github/meguminisha/PCVK22-23/blob/main/Week2_Agung_Putra_Pamungkas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive


# Accessing my google drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/Capybara.jpg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/Capybara.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)
fig = plt.figure(figsize=(10,10))   #ubah sesuai kebutuhan
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
#perhatikan koordinat titik pt1 dan pt2 , pojok kiri atas dan pojok kanan bawah
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
#inisialisasi numpy array type data int32
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
#reshape array
pts = vertices.reshape((-1,1,2)) 
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# # Pertanyaan
#
# 1. Apakah perbedaan gambar yang ditampilkan tanpa dan dengan matplotlib?
# - Gambar yang menggunakan matplotlib akan ada plot grafik daripada gambar yang tidak menggunakan matplotlib
#
# 2. Apakah perbedaan dan pengaruhnya pembuatan black image antara tipe data int16 dan int32?
# - penggunaan int32 memiliki penyimpanan bit yang lebih besar daripada int16
#
# 3. Jelaskan tentang angka-angka yang terdapat pada reshape((-1,1,2))
# - ketiga angka dalam bentuk array mendeskripsikan warna,Merah,Hijau,Biru.
#
# 4. Apakah kegunaan "google.colab.patches import cv2_imshow"
# - code ini berguna untuk memasukkan gambar pada open CV ke Google Collab
#
# 5. Apakah kegunaan “skimage impot io” pada potongan kode soal nomor 4
# - kegunaan kode ini untuk memproses gambar

# %% [markdown]
# # Tugas
# 1. Tampilkan image dalam channel Red-Green dan Green-Blue saja|

# %%
#Red-Green
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
img3[:,:,2] = 0
plt.imshow(img3)

# %%
#Green-Blue
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
img3[:,:,0] = 0
plt.imshow(img3)

# %% [markdown]
# 2. Tampilkan baris ke 10-100, kolom 10-100!

# %%
plt.imshow(img[10:100, 10:100])

# %% [markdown]
# 3. Tampilkan image baris ke 5-30, semua kolom, channel Green saja!

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
img3[:,:,(0,2)] = 0
plt.imshow(img3[5:30])

# %% [markdown]
# 4. Buat 5 kotak berbagai ukuran dan warna yang berbeda dalam satu image. disarankan menggunakan bilangan acak/random

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
cv.rectangle(img3,pt1=(1600,1200),pt2=(3500,2700),color=(255,0,0),thickness=10)
cv.rectangle(img3,pt1=(1900,2000),pt2=(1800,2500),color=(0,255,0),thickness=10)
cv.rectangle(img3,pt1=(300,1500),pt2=(3900,2700),color=(0,0,255),thickness=10)
cv.rectangle(img3,pt1=(2800,2700),pt2=(400,1500),color=(0,255,255),thickness=10)
cv.rectangle(img3,pt1=(4000,2400),pt2=(1900,2300),color=(255,255,255),thickness=10)
plt.imshow(img3)

# %% [markdown]
# 5. Tampilkan image dengan posisi terbalik!

# %%
img = cv.imread('/content/drive/MyDrive/Capybara.jpg')
img_flip = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB), 0)
plt.imshow(img_flip)

# %% [markdown]
# 6. Buat rectangle dan circle pada bagian wajah

# %%
# Buat rectangle dan circle pada bagian wajah 
img = cv.imread('/content/drive/MyDrive/Capybara.jpg')
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
cv.circle(img3, (2400,1500), 700, (255,0,0), 10)
cv.rectangle(img3,pt1=(1500,2100),pt2=(3000,900),color=(0,255,0),thickness=10)
plt.imshow(img3)

# %% [markdown]
# 7. Buat rectangle pada bagian sudut bawah kiri channel B pada color space RGB pada gambar

# %%
img = cv.imread('/content/drive/MyDrive/Capybara.jpg')
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
img3[:,:,(0,1)] = 0
cv.rectangle(img3,pt1=(100,3900),pt2=(800,3200),color=(255,0,0),thickness=50)
plt.imshow(img3)
